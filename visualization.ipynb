# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
df = pd.concat([pd.read_csv('experiment_results/' + file) for file in os.listdir('experiment_results')])
df.index = os.listdir('experiment_results')
df.to_csv('experiment_results.csv')
metrics = df[["insert_time", "query_time", "false_positive_rate", "true_positives", "num_sequences", "sbt_size"]]

# %%
metrics.sort_values('query_time')
# Out:
#                                                     insert_time  query_time  \
# threshold1.csv                                       165.139340    1.451120
# hash_fraction0.5.csv                                  90.862993    5.654910
# num_sequences100.csv                                  60.094754    5.785523
# node_classHowDetsimilarity_functionfunction jac...   155.198886    6.752932
# node_classHowDetquery_methodFast.csv                 139.105701    6.864587
# node_classHowDetinsert_methodCluster2.csv            134.564864    6.990266
# node_classHowDetinsert_methodGreedy.csv              277.565521    7.014183
# node_classHowDetsimilarity_functionfunction cos...   157.111696    7.288502
# node_classHowDetsimilarity_functionfunction ham...   160.498672    7.506917
# node_classHowDetinsert_methodCluster1.csv            178.052688    7.594684
# query_size250.csv                                    157.328159    7.645549
# ...
